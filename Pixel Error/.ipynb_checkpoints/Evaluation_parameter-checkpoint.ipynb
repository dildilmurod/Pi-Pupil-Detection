# %%
import numpy as np
import pandas as pd
import glob

# %%
import os
print(os.getcwd())
# Out:
# /home/demo/Desktop/Pi-Pupil-Detection/Pixel Error

# %%
cols = ['x', 'y']
# For one participant multiple data recording parts were used in LPW 
#1 - [1,4,9]   2 - [4,10,13]   3 - [16,19,21]  4 - [1,2,12]  5 - [6,10,11]
#6 - [2,5,13]  7 - [15,18,21]  8 - [2,7,9]  9 - [16,17,18]  10 - [1,8,11]

PATICIPANT_PART = 1
PATICIPANT_NUM = 1

canny_blur = [[i,j] for i in range(6,51,3) for j in range(7,29,2)]
# canny_blur = [[6, 9], [9, 11], [24,23]]

path = rf"dataset/LPW_example/LPW_subject{PATICIPANT_NUM}"

print("Participant number: ", PATICIPANT_NUM, "  -  ", " part: ", PATICIPANT_PART)
# Out:
# Participant number:  4   -    part:  2

# %%
detection_rate_result = pd.DataFrame(columns = ['PATICIPANT_NUM', 'PATICIPANT_PART', 'CANNY_VALUE', 'BLUR_VALUE', 'IDENTIFIED', 'DETECTION_RATE_2PIX', 'DETECTION_RATE_5PIX', 'DETECTION_RATE_10PIX', 'DETECTION_RATE_20PIX', 'FRAME_SIZE'])
#detection_rate_result = pd.read_csv(path + rf'/detect_participant{PATICIPANT_NUM}.csv', delimiter=',')

# %%
for CANNY, BLUR in canny_blur:
    print("CANNY: ", CANNY, "  -  ", " BLUR: ", BLUR)
    # detection_observed = pd.read_csv(path + rf'/320PEst_Experiment_{PATICIPANT_PART}_canny_{CANNY}_blur_{BLUR}.csv', delimiter='\t')
    detection_observed = pd.read_csv(path + rf'/320PEst_Experiment_1_canny_{CANNY}_blur_{BLUR}.csv', delimiter='\t')
    
    detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
    detection_actual.columns = cols
    detection_actual[cols] = detection_actual[cols].astype('float')
    detection_observed[cols] = detection_observed[cols].astype('float')

    detection_actual = detection_actual/2
    
    observed_num = len(detection_observed)
    misidentified = len(detection_observed[(detection_observed.extra != '[]') & (detection_observed.x != 0)])
    print('Misidentified: ', misidentified)
    
    notidentified = len(detection_observed[(detection_observed.x == 0)])
    print('Not identified: ', notidentified)
    
    identified = observed_num - misidentified - notidentified 
    print('Identified: ', (identified * 100) / observed_num)
    
    detection_observed[cols] - detection_actual[cols] 
    
    # Error calculation (MSE)
    
    evaluation = []
    
    for data_o, data_a in zip(detection_observed.values, detection_actual.values):
        #print(np.linalg.norm([data_o[0] , data_a[0]], 1))
        ecu_dist = np.sqrt(np.square(data_o[0] - data_a[0]) + np.square(data_o[1] - data_a[1]))
        evaluation.append(ecu_dist)
        #np.linalg.norm([data_o[0], data_o[1]], [data_a[0], data_a[1]], axis=1)

    error_evaluation_2pix =  list(filter(lambda value: value < 2, evaluation))
    tolerated_detection_2pix = (len(error_evaluation_2pix) * 100) / observed_num
    
    error_evaluation_5pix =  list(filter(lambda value: value < 5, evaluation))
    tolerated_detection_5pix = (len(error_evaluation_5pix) * 100) / observed_num
    
    error_evaluation_10pix =  list(filter(lambda value: value < 10, evaluation))
    tolerated_detection_10pix = (len(error_evaluation_10pix) * 100) / observed_num

    error_evaluation_20pix =  list(filter(lambda value: value < 20, evaluation))
    tolerated_detection_20pix = (len(error_evaluation_20pix) * 100) / observed_num
    
    
    # df_experiment = pd.DataFrame(filter_evaluation, columns=["Error_Euclidean"])
    
    # df_experiment.to_csv(path + f"/participant{PATICIPANT_NUM}_part_{PATICIPANT_PART}_error__canny_{CANNY}_blur_{BLUR}.csv",
    #                     sep=',', index=False)
    
    detection_rate_result.loc[len(detection_rate_result.index)] = [PATICIPANT_NUM, PATICIPANT_PART, CANNY, BLUR, identified, tolerated_detection_2pix, tolerated_detection_5pix, tolerated_detection_10pix, tolerated_detection_20pix, '320x240']
    print(detection_rate_result)
    print("")
# Out:
# CANNY:  6   -    BLUR:  7
# Misidentified:  36
# Not identified:  937
# Identified:  51.35
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#    PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0               4                2            6           7        1027
#
#    DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                29.45                 42.8                 48.95
#
#    DETECTION_RATE_20PIX FRAME_SIZE
# 0                 50.65    320x240
#
# CANNY:  6   -    BLUR:  9
# Misidentified:  20
# Not identified:  867
# Identified:  55.65
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#    PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0               4                2            6           7        1027
# 1               4                2            6           9        1113
#
#    DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                29.45                42.80                 48.95
# 1                33.70                46.25                 52.65
#
#    DETECTION_RATE_20PIX FRAME_SIZE
# 0                 50.65    320x240
# 1                 54.85    320x240
#
# CANNY:  6   -    BLUR:  11
# Misidentified:  7
# Not identified:  865
# Identified:  56.4
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#    PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0               4                2            6           7        1027
# 1               4                2            6           9        1113
# 2               4                2            6          11        1128
#
#    DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                29.45                42.80                 48.95
# 1                33.70                46.25                 52.65
# 2                36.10                49.35                 54.15
#
#    DETECTION_RATE_20PIX FRAME_SIZE
# 0                 50.65    320x240
# 1                 54.85    320x240
# 2                 55.90    320x240
#
# CANNY:  6   -    BLUR:  13
# Misidentified:  6
# Not identified:  863
# Identified:  56.55
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#    PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0               4                2            6           7        1027
# 1               4                2            6           9        1113
# 2               4                2            6          11        1128
# 3               4                2            6          13        1131
#
#    DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                29.45                42.80                 48.95
# 1                33.70                46.25                 52.65
# 2                36.10                49.35                 54.15
# 3                35.35                49.90                 54.65
#
#    DETECTION_RATE_20PIX FRAME_SIZE
# 0                 50.65    320x240
# 1                 54.85    320x240
# 2                 55.90    320x240
# 3                 56.15    320x240
#
# CANNY:  6   -    BLUR:  15
# Misidentified:  8
# Not identified:  877
# Identified:  55.75
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#    PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0               4                2            6           7        1027
# 1               4                2            6           9        1113
# 2               4                2            6          11        1128
# 3               4                2            6          13        1131
# 4               4                2            6          15        1115
#
#    DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                29.45                42.80                 48.95
# 1                33.70                46.25                 52.65
# 2                36.10                49.35                 54.15
# 3                35.35                49.90                 54.65
# 4                33.90                49.25                 53.70
#
#    DETECTION_RATE_20PIX FRAME_SIZE
# 0                 50.65    320x240
# 1                 54.85    320x240
# 2                 55.90    320x240
# 3                 56.15    320x240
# 4                 55.10    320x240
#
# CANNY:  6   -    BLUR:  17
# Misidentified:  6
# Not identified:  906
# Identified:  54.4
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#    PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0               4                2            6           7        1027
# 1               4                2            6           9        1113
# 2               4                2            6          11        1128
# 3               4                2            6          13        1131
# 4               4                2            6          15        1115
# 5               4                2            6          17        1088
#
#    DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                29.45                42.80                 48.95
# 1                33.70                46.25                 52.65
# 2                36.10                49.35                 54.15
# 3                35.35                49.90                 54.65
# 4                33.90                49.25                 53.70
# 5                29.95                47.40                 51.75
#
#    DETECTION_RATE_20PIX FRAME_SIZE
# 0                 50.65    320x240
# 1                 54.85    320x240
# 2                 55.90    320x240
# 3                 56.15    320x240
# 4                 55.10    320x240
# 5                 53.90    320x240
#
# CANNY:  6   -    BLUR:  19
# Misidentified:  10
# Not identified:  979
# Identified:  50.55
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#    PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0               4                2            6           7        1027
# 1               4                2            6           9        1113
# 2               4                2            6          11        1128
# 3               4                2            6          13        1131
# 4               4                2            6          15        1115
# 5               4                2            6          17        1088
# 6               4                2            6          19        1011
#
#    DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                29.45                42.80                 48.95
# 1                33.70                46.25                 52.65
# 2                36.10                49.35                 54.15
# 3                35.35                49.90                 54.65
# 4                33.90                49.25                 53.70
# 5                29.95                47.40                 51.75
# 6                25.05                44.65                 48.60
#
#    DETECTION_RATE_20PIX FRAME_SIZE
# 0                 50.65    320x240
# 1                 54.85    320x240
# 2                 55.90    320x240
# 3                 56.15    320x240
# 4                 55.10    320x240
# 5                 53.90    320x240
# 6                 50.45    320x240
#
# CANNY:  6   -    BLUR:  21
# Misidentified:  13
# Not identified:  1035
# Identified:  47.6
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#    PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0               4                2            6           7        1027
# 1               4                2            6           9        1113
# 2               4                2            6          11        1128
# 3               4                2            6          13        1131
# 4               4                2            6          15        1115
# 5               4                2            6          17        1088
# 6               4                2            6          19        1011
# 7               4                2            6          21         952
#
#    DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                29.45                42.80                 48.95
# 1                33.70                46.25                 52.65
# 2                36.10                49.35                 54.15
# 3                35.35                49.90                 54.65
# 4                33.90                49.25                 53.70
# 5                29.95                47.40                 51.75
# 6                25.05                44.65                 48.60
# 7                20.80                40.40                 45.50
#
#    DETECTION_RATE_20PIX FRAME_SIZE
# 0                 50.65    320x240
# 1                 54.85    320x240
# 2                 55.90    320x240
# 3                 56.15    320x240
# 4                 55.10    320x240
# 5                 53.90    320x240
# 6                 50.45    320x240
# 7                 47.20    320x240
#
# CANNY:  6   -    BLUR:  23
# Misidentified:  13
# Not identified:  1100
# Identified:  44.35
#    PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0               4                2            6           7        1027
# 1               4                2            6           9        1113
# 2               4                2            6          11        1128
# 3               4                2            6          13        1131
# 4               4                2            6          15        1115
# 5               4                2            6          17        1088
# 6               4                2            6          19        1011
# 7               4                2            6          21         952
# 8               4                2            6          23         887
#
#    DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                29.45                42.80                 48.95
# 1                33.70                46.25                 52.65
# 2                36.10                49.35                 54.15
# 3                35.35                49.90                 54.65
# 4                33.90                49.25                 53.70
# 5                29.95                47.40                 51.75
# 6                25.05                44.65                 48.60
# 7                20.80                40.40                 45.50
# 8                19.30                37.95                 42.70
#
#    DETECTION_RATE_20PIX FRAME_SIZE
# 0                 50.65    320x240
# 1                 54.85    320x240
# 2                 55.90    320x240
# 3                 56.15    320x240
# 4                 55.10    320x240
# 5                 53.90    320x240
# 6                 50.45    320x240
# 7                 47.20    320x240
# 8                 43.95    320x240
#
# CANNY:  6   -    BLUR:  25
# Misidentified:  4
# Not identified:  1145
# Identified:  42.55
#    PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0               4                2            6           7        1027
# 1               4                2            6           9        1113
# 2               4                2            6          11        1128
# 3               4                2            6          13        1131
# 4               4                2            6          15        1115
# 5               4                2            6          17        1088
# 6               4                2            6          19        1011
# 7               4                2            6          21         952
# 8               4                2            6          23         887
# 9               4                2            6          25         851
#
#    DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                29.45                42.80                 48.95
# 1                33.70                46.25                 52.65
# 2                36.10                49.35                 54.15
# 3                35.35                49.90                 54.65
# 4                33.90                49.25                 53.70
# 5                29.95                47.40                 51.75
# 6                25.05                44.65                 48.60
# 7                20.80                40.40                 45.50
# 8                19.30                37.95                 42.70
# 9                18.15                37.95                 41.65
#
#    DETECTION_RATE_20PIX FRAME_SIZE
# 0                 50.65    320x240
# 1                 54.85    320x240
# 2                 55.90    320x240
# 3                 56.15    320x240
# 4                 55.10    320x240
# 5                 53.90    320x240
# 6                 50.45    320x240
# 7                 47.20    320x240
# 8                 43.95    320x240
# 9                 42.40    320x240
#
# CANNY:  6   -    BLUR:  27
# Misidentified:  9
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# Not identified:  1219
# Identified:  38.6
#     PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                4                2            6           7        1027
# 1                4                2            6           9        1113
# 2                4                2            6          11        1128
# 3                4                2            6          13        1131
# 4                4                2            6          15        1115
# 5                4                2            6          17        1088
# 6                4                2            6          19        1011
# 7                4                2            6          21         952
# 8                4                2            6          23         887
# 9                4                2            6          25         851
# 10               4                2            6          27         772
#
#     DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                 29.45                42.80                 48.95
# 1                 33.70                46.25                 52.65
# 2                 36.10                49.35                 54.15
# 3                 35.35                49.90                 54.65
# 4                 33.90                49.25                 53.70
# 5                 29.95                47.40                 51.75
# 6                 25.05                44.65                 48.60
# 7                 20.80                40.40                 45.50
# 8                 19.30                37.95                 42.70
# 9                 18.15                37.95                 41.65
# 10                15.45                34.75                 37.70
#
#     DETECTION_RATE_20PIX FRAME_SIZE
# 0                  50.65    320x240
# 1                  54.85    320x240
# 2                  55.90    320x240
# 3                  56.15    320x240
# 4                  55.10    320x240
# 5                  53.90    320x240
# 6                  50.45    320x240
# 7                  47.20    320x240
# 8                  43.95    320x240
# 9                  42.40    320x240
# 10                 38.35    320x240
#
# CANNY:  9   -    BLUR:  7
# Misidentified:  32
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# Not identified:  935
# Identified:  51.65
#     PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                4                2            6           7        1027
# 1                4                2            6           9        1113
# 2                4                2            6          11        1128
# 3                4                2            6          13        1131
# 4                4                2            6          15        1115
# 5                4                2            6          17        1088
# 6                4                2            6          19        1011
# 7                4                2            6          21         952
# 8                4                2            6          23         887
# 9                4                2            6          25         851
# 10               4                2            6          27         772
# 11               4                2            9           7        1033
#
#     DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                 29.45                42.80                 48.95
# 1                 33.70                46.25                 52.65
# 2                 36.10                49.35                 54.15
# 3                 35.35                49.90                 54.65
# 4                 33.90                49.25                 53.70
# 5                 29.95                47.40                 51.75
# 6                 25.05                44.65                 48.60
# 7                 20.80                40.40                 45.50
# 8                 19.30                37.95                 42.70
# 9                 18.15                37.95                 41.65
# 10                15.45                34.75                 37.70
# 11                29.65                43.05                 49.20
#
#     DETECTION_RATE_20PIX FRAME_SIZE
# 0                  50.65    320x240
# 1                  54.85    320x240
# 2                  55.90    320x240
# 3                  56.15    320x240
# 4                  55.10    320x240
# 5                  53.90    320x240
# 6                  50.45    320x240
# 7                  47.20    320x240
# 8                  43.95    320x240
# 9                  42.40    320x240
# 10                 38.35    320x240
# 11                 51.00    320x240
#
# CANNY:  9   -    BLUR:  9
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# Misidentified:  19
# Not identified:  866
# Identified:  55.75
#     PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                4                2            6           7        1027
# 1                4                2            6           9        1113
# 2                4                2            6          11        1128
# 3                4                2            6          13        1131
# 4                4                2            6          15        1115
# 5                4                2            6          17        1088
# 6                4                2            6          19        1011
# 7                4                2            6          21         952
# 8                4                2            6          23         887
# 9                4                2            6          25         851
# 10               4                2            6          27         772
# 11               4                2            9           7        1033
# 12               4                2            9           9        1115
#
#     DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                 29.45                42.80                 48.95
# 1                 33.70                46.25                 52.65
# 2                 36.10                49.35                 54.15
# 3                 35.35                49.90                 54.65
# 4                 33.90                49.25                 53.70
# 5                 29.95                47.40                 51.75
# 6                 25.05                44.65                 48.60
# 7                 20.80                40.40                 45.50
# 8                 19.30                37.95                 42.70
# 9                 18.15                37.95                 41.65
# 10                15.45                34.75                 37.70
# 11                29.65                43.05                 49.20
# 12                33.65                46.35                 52.75
#
#     DETECTION_RATE_20PIX FRAME_SIZE
# 0                  50.65    320x240
# 1                  54.85    320x240
# 2                  55.90    320x240
# 3                  56.15    320x240
# 4                  55.10    320x240
# 5                  53.90    320x240
# 6                  50.45    320x240
# 7                  47.20    320x240
# 8                  43.95    320x240
# 9                  42.40    320x240
# 10                 38.35    320x240
# 11                 51.00    320x240
# 12                 54.90    320x240
#
# CANNY:  9   -    BLUR:  11
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# Misidentified:  7
# Not identified:  863
# Identified:  56.5
#     PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                4                2            6           7        1027
# 1                4                2            6           9        1113
# 2                4                2            6          11        1128
# 3                4                2            6          13        1131
# 4                4                2            6          15        1115
# 5                4                2            6          17        1088
# 6                4                2            6          19        1011
# 7                4                2            6          21         952
# 8                4                2            6          23         887
# 9                4                2            6          25         851
# 10               4                2            6          27         772
# 11               4                2            9           7        1033
# 12               4                2            9           9        1115
# 13               4                2            9          11        1130
#
#     DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                 29.45                42.80                 48.95
# 1                 33.70                46.25                 52.65
# 2                 36.10                49.35                 54.15
# 3                 35.35                49.90                 54.65
# 4                 33.90                49.25                 53.70
# 5                 29.95                47.40                 51.75
# 6                 25.05                44.65                 48.60
# 7                 20.80                40.40                 45.50
# 8                 19.30                37.95                 42.70
# 9                 18.15                37.95                 41.65
# 10                15.45                34.75                 37.70
# 11                29.65                43.05                 49.20
# 12                33.65                46.35                 52.75
# 13                36.30                49.45                 54.25
#
#     DETECTION_RATE_20PIX FRAME_SIZE
# 0                  50.65    320x240
# 1                  54.85    320x240
# 2                  55.90    320x240
# 3                  56.15    320x240
# 4                  55.10    320x240
# 5                  53.90    320x240
# 6                  50.45    320x240
# 7                  47.20    320x240
# 8                  43.95    320x240
# 9                  42.40    320x240
# 10                 38.35    320x240
# 11                 51.00    320x240
# 12                 54.90    320x240
# 13                 56.05    320x240
#
# CANNY:  9   -    BLUR:  13
# Misidentified:  6
# Not identified:  864
# Identified:  56.5
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#     PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                4                2            6           7        1027
# 1                4                2            6           9        1113
# 2                4                2            6          11        1128
# 3                4                2            6          13        1131
# 4                4                2            6          15        1115
# 5                4                2            6          17        1088
# 6                4                2            6          19        1011
# 7                4                2            6          21         952
# 8                4                2            6          23         887
# 9                4                2            6          25         851
# 10               4                2            6          27         772
# 11               4                2            9           7        1033
# 12               4                2            9           9        1115
# 13               4                2            9          11        1130
# 14               4                2            9          13        1130
#
#     DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                 29.45                42.80                 48.95
# 1                 33.70                46.25                 52.65
# 2                 36.10                49.35                 54.15
# 3                 35.35                49.90                 54.65
# 4                 33.90                49.25                 53.70
# 5                 29.95                47.40                 51.75
# 6                 25.05                44.65                 48.60
# 7                 20.80                40.40                 45.50
# 8                 19.30                37.95                 42.70
# 9                 18.15                37.95                 41.65
# 10                15.45                34.75                 37.70
# 11                29.65                43.05                 49.20
# 12                33.65                46.35                 52.75
# 13                36.30                49.45                 54.25
# 14                35.45                50.00                 54.70
#
#     DETECTION_RATE_20PIX FRAME_SIZE
# 0                  50.65    320x240
# 1                  54.85    320x240
# 2                  55.90    320x240
# 3                  56.15    320x240
# 4                  55.10    320x240
# 5                  53.90    320x240
# 6                  50.45    320x240
# 7                  47.20    320x240
# 8                  43.95    320x240
# 9                  42.40    320x240
# 10                 38.35    320x240
# 11                 51.00    320x240
# 12                 54.90    320x240
# 13                 56.05    320x240
# 14                 56.15    320x240
#
# CANNY:  9   -    BLUR:  15
# Misidentified:  6
# Not identified:  878
# Identified:  55.8
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#     PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                4                2            6           7        1027
# 1                4                2            6           9        1113
# 2                4                2            6          11        1128
# 3                4                2            6          13        1131
# 4                4                2            6          15        1115
# 5                4                2            6          17        1088
# 6                4                2            6          19        1011
# 7                4                2            6          21         952
# 8                4                2            6          23         887
# 9                4                2            6          25         851
# 10               4                2            6          27         772
# 11               4                2            9           7        1033
# 12               4                2            9           9        1115
# 13               4                2            9          11        1130
# 14               4                2            9          13        1130
# 15               4                2            9          15        1116
#
#     DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                 29.45                42.80                 48.95
# 1                 33.70                46.25                 52.65
# 2                 36.10                49.35                 54.15
# 3                 35.35                49.90                 54.65
# 4                 33.90                49.25                 53.70
# 5                 29.95                47.40                 51.75
# 6                 25.05                44.65                 48.60
# 7                 20.80                40.40                 45.50
# 8                 19.30                37.95                 42.70
# 9                 18.15                37.95                 41.65
# 10                15.45                34.75                 37.70
# 11                29.65                43.05                 49.20
# 12                33.65                46.35                 52.75
# 13                36.30                49.45                 54.25
# 14                35.45                50.00                 54.70
# 15                33.95                49.30                 53.85
#
#     DETECTION_RATE_20PIX FRAME_SIZE
# 0                  50.65    320x240
# 1                  54.85    320x240
# 2                  55.90    320x240
# 3                  56.15    320x240
# 4                  55.10    320x240
# 5                  53.90    320x240
# 6                  50.45    320x240
# 7                  47.20    320x240
# 8                  43.95    320x240
# 9                  42.40    320x240
# 10                 38.35    320x240
# 11                 51.00    320x240
# 12                 54.90    320x240
# 13                 56.05    320x240
# 14                 56.15    320x240
# 15                 55.25    320x240
#
# CANNY:  9   -    BLUR:  17
# Misidentified:  5
# Not identified:  906
# Identified:  54.45
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#     PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                4                2            6           7        1027
# 1                4                2            6           9        1113
# 2                4                2            6          11        1128
# 3                4                2            6          13        1131
# 4                4                2            6          15        1115
# 5                4                2            6          17        1088
# 6                4                2            6          19        1011
# 7                4                2            6          21         952
# 8                4                2            6          23         887
# 9                4                2            6          25         851
# 10               4                2            6          27         772
# 11               4                2            9           7        1033
# 12               4                2            9           9        1115
# 13               4                2            9          11        1130
# 14               4                2            9          13        1130
# 15               4                2            9          15        1116
# 16               4                2            9          17        1089
#
#     DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                 29.45                42.80                 48.95
# 1                 33.70                46.25                 52.65
# 2                 36.10                49.35                 54.15
# 3                 35.35                49.90                 54.65
# 4                 33.90                49.25                 53.70
# 5                 29.95                47.40                 51.75
# 6                 25.05                44.65                 48.60
# 7                 20.80                40.40                 45.50
# 8                 19.30                37.95                 42.70
# 9                 18.15                37.95                 41.65
# 10                15.45                34.75                 37.70
# 11                29.65                43.05                 49.20
# 12                33.65                46.35                 52.75
# 13                36.30                49.45                 54.25
# 14                35.45                50.00                 54.70
# 15                33.95                49.30                 53.85
# 16                29.90                47.45                 51.80
#
#     DETECTION_RATE_20PIX FRAME_SIZE
# 0                  50.65    320x240
# 1                  54.85    320x240
# 2                  55.90    320x240
# 3                  56.15    320x240
# 4                  55.10    320x240
# 5                  53.90    320x240
# 6                  50.45    320x240
# 7                  47.20    320x240
# 8                  43.95    320x240
# 9                  42.40    320x240
# 10                 38.35    320x240
# 11                 51.00    320x240
# 12                 54.90    320x240
# 13                 56.05    320x240
# 14                 56.15    320x240
# 15                 55.25    320x240
# 16                 53.95    320x240
#
# CANNY:  9   -    BLUR:  19
# Misidentified:  10
# Not identified:  980
# Identified:  50.5
#     PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                4                2            6           7        1027
# 1                4                2            6           9        1113
# 2                4                2            6          11        1128
# 3                4                2            6          13        1131
# 4                4                2            6          15        1115
# 5                4                2            6          17        1088
# 6                4                2            6          19        1011
# 7                4                2            6          21         952
# 8                4                2            6          23         887
# 9                4                2            6          25         851
# 10               4                2            6          27         772
# 11               4                2            9           7        1033
# 12               4                2            9           9        1115
# 13               4                2            9          11        1130
# 14               4                2            9          13        1130
# 15               4                2            9          15        1116
# 16               4                2            9          17        1089
# 17               4                2            9          19        1010
#
#     DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                 29.45                42.80                 48.95
# 1                 33.70                46.25                 52.65
# 2                 36.10                49.35                 54.15
# 3                 35.35                49.90                 54.65
# 4                 33.90                49.25                 53.70
# 5                 29.95                47.40                 51.75
# 6                 25.05                44.65                 48.60
# 7                 20.80                40.40                 45.50
# 8                 19.30                37.95                 42.70
# 9                 18.15                37.95                 41.65
# 10                15.45                34.75                 37.70
# 11                29.65                43.05                 49.20
# 12                33.65                46.35                 52.75
# 13                36.30                49.45                 54.25
# 14                35.45                50.00                 54.70
# 15                33.95                49.30                 53.85
# 16                29.90                47.45                 51.80
# 17                25.10                44.60                 48.60
#
#     DETECTION_RATE_20PIX FRAME_SIZE
# 0                  50.65    320x240
# 1                  54.85    320x240
# 2                  55.90    320x240
# 3                  56.15    320x240
# 4                  55.10    320x240
# 5                  53.90    320x240
# 6                  50.45    320x240
# 7                  47.20    320x240
# 8                  43.95    320x240
# 9                  42.40    320x240
# 10                 38.35    320x240
# 11                 51.00    320x240
# 12                 54.90    320x240
# 13                 56.05    320x240
# 14                 56.15    320x240
# 15                 55.25    320x240
# 16                 53.95    320x240
# 17                 50.40    320x240
#
# CANNY:  9   -    BLUR:  21
# Misidentified:  13
# Not identified:  1036
# Identified:  47.55
#     PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                4                2            6           7        1027
# 1                4                2            6           9        1113
# 2                4                2            6          11        1128
# 3                4                2            6          13        1131
# 4                4                2            6          15        1115
# 5                4                2            6          17        1088
# 6                4                2            6          19        1011
# 7                4                2            6          21         952
# 8                4                2            6          23         887
# 9                4                2            6          25         851
# 10               4                2            6          27         772
# 11               4                2            9           7        1033
# 12               4                2            9           9        1115
# 13               4                2            9          11        1130
# 14               4                2            9          13        1130
# 15               4                2            9          15        1116
# 16               4                2            9          17        1089
# 17               4                2            9          19        1010
# 18               4                2            9          21         951
#
#     DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                 29.45                42.80                 48.95
# 1                 33.70                46.25                 52.65
# 2                 36.10                49.35                 54.15
# 3                 35.35                49.90                 54.65
# 4                 33.90                49.25                 53.70
# 5                 29.95                47.40                 51.75
# 6                 25.05                44.65                 48.60
# 7                 20.80                40.40                 45.50
# 8                 19.30                37.95                 42.70
# 9                 18.15                37.95                 41.65
# 10                15.45                34.75                 37.70
# 11                29.65                43.05                 49.20
# 12                33.65                46.35                 52.75
# 13                36.30                49.45                 54.25
# 14                35.45                50.00                 54.70
# 15                33.95                49.30                 53.85
# 16                29.90                47.45                 51.80
# 17                25.10                44.60                 48.60
# 18                21.15                40.40                 45.50
#
#     DETECTION_RATE_20PIX FRAME_SIZE
# 0                  50.65    320x240
# 1                  54.85    320x240
# 2                  55.90    320x240
# 3                  56.15    320x240
# 4                  55.10    320x240
# 5                  53.90    320x240
# 6                  50.45    320x240
# 7                  47.20    320x240
# 8                  43.95    320x240
# 9                  42.40    320x240
# 10                 38.35    320x240
# 11                 51.00    320x240
# 12                 54.90    320x240
# 13                 56.05    320x240
# 14                 56.15    320x240
# 15                 55.25    320x240
# 16                 53.95    320x240
# 17                 50.40    320x240
# 18                 47.20    320x240
#
# CANNY:  9   -    BLUR:  23
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# Misidentified:  10
# Not identified:  1101
# Identified:  44.45
#     PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                4                2            6           7        1027
# 1                4                2            6           9        1113
# 2                4                2            6          11        1128
# 3                4                2            6          13        1131
# 4                4                2            6          15        1115
# 5                4                2            6          17        1088
# 6                4                2            6          19        1011
# 7                4                2            6          21         952
# 8                4                2            6          23         887
# 9                4                2            6          25         851
# 10               4                2            6          27         772
# 11               4                2            9           7        1033
# 12               4                2            9           9        1115
# 13               4                2            9          11        1130
# 14               4                2            9          13        1130
# 15               4                2            9          15        1116
# 16               4                2            9          17        1089
# 17               4                2            9          19        1010
# 18               4                2            9          21         951
# 19               4                2            9          23         889
#
#     DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                 29.45                42.80                 48.95
# 1                 33.70                46.25                 52.65
# 2                 36.10                49.35                 54.15
# 3                 35.35                49.90                 54.65
# 4                 33.90                49.25                 53.70
# 5                 29.95                47.40                 51.75
# 6                 25.05                44.65                 48.60
# 7                 20.80                40.40                 45.50
# ...
# 157                 56.35    320x240
# 158                 51.60    320x240
#
# [159 rows x 10 columns]
#
# CANNY:  48   -    BLUR:  17
# Misidentified:  2
# Not identified:  1097
# Identified:  45.05
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#      PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                 4                2            6           7        1027
# 1                 4                2            6           9        1113
# 2                 4                2            6          11        1128
# 3                 4                2            6          13        1131
# 4                 4                2            6          15        1115
# ..              ...              ...          ...         ...         ...
# 155               4                2           48           9        1180
# 156               4                2           48          11        1166
# 157               4                2           48          13        1126
# 158               4                2           48          15        1032
# 159               4                2           48          17         901
#
#      DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                  29.45                42.80                 48.95
# 1                  33.70                46.25                 52.65
# 2                  36.10                49.35                 54.15
# 3                  35.35                49.90                 54.65
# 4                  33.90                49.25                 53.70
# ..                   ...                  ...                   ...
# 155                36.90                50.20                 55.75
# 156                37.90                50.90                 55.45
# 157                34.20                48.60                 53.65
# 158                29.30                45.10                 49.40
# 159                22.75                38.15                 42.10
#
#      DETECTION_RATE_20PIX FRAME_SIZE
# 0                   50.65    320x240
# 1                   54.85    320x240
# 2                   55.90    320x240
# 3                   56.15    320x240
# 4                   55.10    320x240
# ..                    ...        ...
# 155                 58.50    320x240
# 156                 58.20    320x240
# 157                 56.35    320x240
# 158                 51.60    320x240
# 159                 45.15    320x240
#
# [160 rows x 10 columns]
#
# CANNY:  48   -    BLUR:  19
# Misidentified:  0
# Not identified:  1178
# Identified:  41.1
#      PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                 4                2            6           7        1027
# 1                 4                2            6           9        1113
# 2                 4                2            6          11        1128
# 3                 4                2            6          13        1131
# 4                 4                2            6          15        1115
# ..              ...              ...          ...         ...         ...
# 156               4                2           48          11        1166
# 157               4                2           48          13        1126
# 158               4                2           48          15        1032
# 159               4                2           48          17         901
# 160               4                2           48          19         822
#
#      DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                  29.45                42.80                 48.95
# 1                  33.70                46.25                 52.65
# 2                  36.10                49.35                 54.15
# 3                  35.35                49.90                 54.65
# 4                  33.90                49.25                 53.70
# ..                   ...                  ...                   ...
# 156                37.90                50.90                 55.45
# 157                34.20                48.60                 53.65
# 158                29.30                45.10                 49.40
# 159                22.75                38.15                 42.10
# 160                18.95                35.55                 38.50
#
#      DETECTION_RATE_20PIX FRAME_SIZE
# 0                   50.65    320x240
# 1                   54.85    320x240
# 2                   55.90    320x240
# 3                   56.15    320x240
# 4                   55.10    320x240
# ..                    ...        ...
# 156                 58.20    320x240
# 157                 56.35    320x240
# 158                 51.60    320x240
# 159                 45.15    320x240
# 160                 41.10    320x240
#
# [161 rows x 10 columns]
#
# CANNY:  48   -    BLUR:  21
# Misidentified:  0
# Not identified:  1198
# Identified:  40.1
#      PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                 4                2            6           7        1027
# 1                 4                2            6           9        1113
# 2                 4                2            6          11        1128
# 3                 4                2            6          13        1131
# 4                 4                2            6          15        1115
# ..              ...              ...          ...         ...         ...
# 157               4                2           48          13        1126
# 158               4                2           48          15        1032
# 159               4                2           48          17         901
# 160               4                2           48          19         822
# 161               4                2           48          21         802
#
#      DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                  29.45                42.80                 48.95
# 1                  33.70                46.25                 52.65
# 2                  36.10                49.35                 54.15
# 3                  35.35                49.90                 54.65
# 4                  33.90                49.25                 53.70
# ..                   ...                  ...                   ...
# 157                34.20                48.60                 53.65
# 158                29.30                45.10                 49.40
# 159                22.75                38.15                 42.10
# 160                18.95                35.55                 38.50
# 161                17.40                34.50                 38.05
#
#      DETECTION_RATE_20PIX FRAME_SIZE
# 0                   50.65    320x240
# 1                   54.85    320x240
# 2                   55.90    320x240
# 3                   56.15    320x240
# 4                   55.10    320x240
# ..                    ...        ...
# 157                 56.35    320x240
# 158                 51.60    320x240
# 159                 45.15    320x240
# 160                 41.10    320x240
# 161                 40.10    320x240
#
# [162 rows x 10 columns]
#
# CANNY:  48   -    BLUR:  23
# Misidentified:  0
# Not identified:  1209
# Identified:  39.55
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
# /tmp/ipykernel_15425/2291225741.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   detection_actual = pd.read_csv(path + rf'/{PATICIPANT_PART}.txt', delim_whitespace= True, header=None)
#      PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                 4                2            6           7        1027
# 1                 4                2            6           9        1113
# 2                 4                2            6          11        1128
# 3                 4                2            6          13        1131
# 4                 4                2            6          15        1115
# ..              ...              ...          ...         ...         ...
# 158               4                2           48          15        1032
# 159               4                2           48          17         901
# 160               4                2           48          19         822
# 161               4                2           48          21         802
# 162               4                2           48          23         791
#
#      DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                  29.45                42.80                 48.95
# 1                  33.70                46.25                 52.65
# 2                  36.10                49.35                 54.15
# 3                  35.35                49.90                 54.65
# 4                  33.90                49.25                 53.70
# ..                   ...                  ...                   ...
# 158                29.30                45.10                 49.40
# 159                22.75                38.15                 42.10
# 160                18.95                35.55                 38.50
# 161                17.40                34.50                 38.05
# 162                16.95                34.60                 38.45
#
#      DETECTION_RATE_20PIX FRAME_SIZE
# 0                   50.65    320x240
# 1                   54.85    320x240
# 2                   55.90    320x240
# 3                   56.15    320x240
# 4                   55.10    320x240
# ..                    ...        ...
# 158                 51.60    320x240
# 159                 45.15    320x240
# 160                 41.10    320x240
# 161                 40.10    320x240
# 162                 39.55    320x240
#
# [163 rows x 10 columns]
#
# CANNY:  48   -    BLUR:  25
# Misidentified:  0
# Not identified:  1234
# Identified:  38.3
#      PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                 4                2            6           7        1027
# 1                 4                2            6           9        1113
# 2                 4                2            6          11        1128
# 3                 4                2            6          13        1131
# 4                 4                2            6          15        1115
# ..              ...              ...          ...         ...         ...
# 159               4                2           48          17         901
# 160               4                2           48          19         822
# 161               4                2           48          21         802
# 162               4                2           48          23         791
# 163               4                2           48          25         766
#
#      DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                  29.45                42.80                 48.95
# 1                  33.70                46.25                 52.65
# 2                  36.10                49.35                 54.15
# 3                  35.35                49.90                 54.65
# 4                  33.90                49.25                 53.70
# ..                   ...                  ...                   ...
# 159                22.75                38.15                 42.10
# 160                18.95                35.55                 38.50
# 161                17.40                34.50                 38.05
# 162                16.95                34.60                 38.45
# 163                14.20                34.30                 37.50
#
#      DETECTION_RATE_20PIX FRAME_SIZE
# 0                   50.65    320x240
# 1                   54.85    320x240
# 2                   55.90    320x240
# 3                   56.15    320x240
# 4                   55.10    320x240
# ..                    ...        ...
# 159                 45.15    320x240
# 160                 41.10    320x240
# 161                 40.10    320x240
# 162                 39.55    320x240
# 163                 38.30    320x240
#
# [164 rows x 10 columns]
#
# CANNY:  48   -    BLUR:  27
# Misidentified:  0
# Not identified:  1265
# Identified:  36.75
#      PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                 4                2            6           7        1027
# 1                 4                2            6           9        1113
# 2                 4                2            6          11        1128
# 3                 4                2            6          13        1131
# 4                 4                2            6          15        1115
# ..              ...              ...          ...         ...         ...
# 160               4                2           48          19         822
# 161               4                2           48          21         802
# 162               4                2           48          23         791
# 163               4                2           48          25         766
# 164               4                2           48          27         735
#
#      DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                  29.45                42.80                 48.95
# 1                  33.70                46.25                 52.65
# 2                  36.10                49.35                 54.15
# 3                  35.35                49.90                 54.65
# 4                  33.90                49.25                 53.70
# ..                   ...                  ...                   ...
# 160                18.95                35.55                 38.50
# 161                17.40                34.50                 38.05
# 162                16.95                34.60                 38.45
# 163                14.20                34.30                 37.50
# 164                12.55                33.30                 36.30
#
#      DETECTION_RATE_20PIX FRAME_SIZE
# 0                   50.65    320x240
# 1                   54.85    320x240
# 2                   55.90    320x240
# 3                   56.15    320x240
# 4                   55.10    320x240
# ..                    ...        ...
# 160                 41.10    320x240
# 161                 40.10    320x240
# 162                 39.55    320x240
# 163                 38.30    320x240
# 164                 36.75    320x240
#
# [165 rows x 10 columns]

# %%
detection_rate_result
# Out:
#      PATICIPANT_NUM  PATICIPANT_PART  CANNY_VALUE  BLUR_VALUE  IDENTIFIED  \
# 0                 4                2            6           7        1027
# 1                 4                2            6           9        1113
# 2                 4                2            6          11        1128
# 3                 4                2            6          13        1131
# 4                 4                2            6          15        1115
# ..              ...              ...          ...         ...         ...
# 160               4                2           48          19         822
# 161               4                2           48          21         802
# 162               4                2           48          23         791
# 163               4                2           48          25         766
# 164               4                2           48          27         735
#
#      DETECTION_RATE_2PIX  DETECTION_RATE_5PIX  DETECTION_RATE_10PIX  \
# 0                  29.45                42.80                 48.95
# 1                  33.70                46.25                 52.65
# 2                  36.10                49.35                 54.15
# 3                  35.35                49.90                 54.65
# 4                  33.90                49.25                 53.70
# ..                   ...                  ...                   ...
# 160                18.95                35.55                 38.50
# 161                17.40                34.50                 38.05
# 162                16.95                34.60                 38.45
# 163                14.20                34.30                 37.50
# 164                12.55                33.30                 36.30
#
#      DETECTION_RATE_20PIX FRAME_SIZE
# 0                   50.65    320x240
# 1                   54.85    320x240
# 2                   55.90    320x240
# 3                   56.15    320x240
# 4                   55.10    320x240
# ..                    ...        ...
# 160                 41.10    320x240
# 161                 40.10    320x240
# 162                 39.55    320x240
# 163                 38.30    320x240
# 164                 36.75    320x240
#
# [165 rows x 10 columns]

# %%
detection_rate_result.to_csv(path + f"/320pest_detect_participant{PATICIPANT_NUM}.csv",
                     sep=',', index=False)

# %%
# print(f"mean - {np.mean(filter_evaluation)}, median - {np.median(filter_evaluation)}, STD - {np.std(filter_evaluation)}")

# %%
# num_not_evaluated = len(evaluation) - len(filter_evaluation)
#max(filter_evaluation)
